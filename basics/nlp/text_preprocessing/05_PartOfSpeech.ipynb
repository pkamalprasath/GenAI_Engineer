# %% [markdown]
# ### Part of Speech

# %%
paragraph="""In today's fast-moving world, people are constantly looking for better ways to stay healthy and productive. 
While many individuals try to follow a balanced diet, the reality is that most of them struggle to maintain consistency. 
The pressure of work, family responsibilities, and daily travel often makes it difficult to focus on proper nutrition. 
Because of this, a large number of people depend on quick snacks and ready-made meals, even though they know these foods are not always the best choices. 
To improve their lifestyle, some people have started exploring options like millet-based foods, natural sweeteners, and homemade snacks. 
These alternatives are becoming popular because they are easy to prepare, gentle on the stomach, and provide long-lasting energy. 
At the same time, technology plays an important role in how people make food decisions. 
The recommendations they see on their phones, the reviews they read online, and the advertisements they watch on social media all influence what they buy. 
With so much information available, learning how to clean text, remove stop words, and analyze data helps researchers understand people's real preferences more accurately.
"""

# %%
from nltk.corpus import stopwords 
sentences=nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ["In today's fast-moving world, people are constantly looking for better ways to stay healthy and productive.",
#  'While many individuals try to follow a balanced diet, the reality is that most of them struggle to maintain consistency.',
#  'The pressure of work, family responsibilities, and daily travel often makes it difficult to focus on proper nutrition.',
#  'Because of this, a large number of people depend on quick snacks and ready-made meals, even though they know these foods are not always the best choices.',
#  'To improve their lifestyle, some people have started exploring options like millet-based foods, natural sweeteners, and homemade snacks.',
#  'These alternatives are becoming popular because they are easy to prepare, gentle on the stomach, and provide long-lasting energy.',
#  'At the same time, technology plays an important role in how people make food decisions.',
#  'The recommendations they see on their phones, the reviews they read online, and the advertisements they watch on social media all influence what they buy.',
#  "With so much information available, learning how to clean text, remove stop words, and analyze data helps researchers understand people's real preferences more accurately."]

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
for i in range(len(sentences)):
   words=nltk.wordpunct_tokenize(sentences[i])
   # Verify each word whether it is stop word or not `
   # apply set to remove duplicates of stop words 
   # find the Part of speech for the output word 
   words=[word for word in words if word not in set(stopwords.words('english')) ]
   pos_tag=nltk.pos_tag(words)
   print(pos_tag)
# Out:
# [('In', 'IN'), ('today', 'NN'), ("'", 'POS'), ('fast', 'JJ'), ('-', ':'), ('moving', 'VBG'), ('world', 'NN'), (',', ','), ('people', 'NNS'), ('constantly', 'RB'), ('looking', 'VBG'), ('better', 'RBR'), ('ways', 'NNS'), ('stay', 'VBP'), ('healthy', 'JJ'), ('productive', 'NN'), ('.', '.')]
# [('While', 'IN'), ('many', 'JJ'), ('individuals', 'NNS'), ('try', 'VBP'), ('follow', 'VB'), ('balanced', 'JJ'), ('diet', 'NN'), (',', ','), ('reality', 'NN'), ('struggle', 'NN'), ('maintain', 'NN'), ('consistency', 'NN'), ('.', '.')]
# [('The', 'DT'), ('pressure', 'NN'), ('work', 'NN'), (',', ','), ('family', 'NN'), ('responsibilities', 'NNS'), (',', ','), ('daily', 'JJ'), ('travel', 'NN'), ('often', 'RB'), ('makes', 'VBZ'), ('difficult', 'JJ'), ('focus', 'VB'), ('proper', 'JJ'), ('nutrition', 'NN'), ('.', '.')]
# [('Because', 'IN'), (',', ','), ('large', 'JJ'), ('number', 'NN'), ('people', 'NNS'), ('depend', 'VBP'), ('quick', 'JJ'), ('snacks', 'NNS'), ('ready', 'JJ'), ('-', ':'), ('made', 'VBN'), ('meals', 'NNS'), (',', ','), ('even', 'RB'), ('though', 'IN'), ('know', 'JJ'), ('foods', 'NNS'), ('always', 'RB'), ('best', 'JJS'), ('choices', 'NNS'), ('.', '.')]
# [('To', 'TO'), ('improve', 'VB'), ('lifestyle', 'NN'), (',', ','), ('people', 'NNS'), ('started', 'VBD'), ('exploring', 'VBG'), ('options', 'NNS'), ('like', 'IN'), ('millet', 'NN'), ('-', ':'), ('based', 'VBN'), ('foods', 'NNS'), (',', ','), ('natural', 'JJ'), ('sweeteners', 'NNS'), (',', ','), ('homemade', 'NN'), ('snacks', 'NNS'), ('.', '.')]
# [('These', 'DT'), ('alternatives', 'NNS'), ('becoming', 'VBG'), ('popular', 'JJ'), ('easy', 'JJ'), ('prepare', 'NN'), (',', ','), ('gentle', 'JJ'), ('stomach', 'NN'), (',', ','), ('provide', 'VBP'), ('long', 'JJ'), ('-', ':'), ('lasting', 'NN'), ('energy', 'NN'), ('.', '.')]
# [('At', 'IN'), ('time', 'NN'), (',', ','), ('technology', 'NN'), ('plays', 'NNS'), ('important', 'JJ'), ('role', 'NN'), ('people', 'NNS'), ('make', 'VBP'), ('food', 'NN'), ('decisions', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('recommendations', 'NNS'), ('see', 'VBP'), ('phones', 'NNS'), (',', ','), ('reviews', 'NNS'), ('read', 'VBP'), ('online', 'NN'), (',', ','), ('advertisements', 'NNS'), ('watch', 'VBP'), ('social', 'JJ'), ('media', 'NNS'), ('influence', 'NN'), ('buy', 'NN'), ('.', '.')]
# [('With', 'IN'), ('much', 'JJ'), ('information', 'NN'), ('available', 'JJ'), (',', ','), ('learning', 'VBG'), ('clean', 'JJ'), ('text', 'NN'), (',', ','), ('remove', 'VB'), ('stop', 'NN'), ('words', 'NNS'), (',', ','), ('analyze', 'NN'), ('data', 'NNS'), ('helps', 'VBZ'), ('researchers', 'NNS'), ('understand', 'JJ'), ('people', 'NNS'), ("'", 'POS'), ('real', 'JJ'), ('preferences', 'NNS'), ('accurately', 'RB'), ('.', '.')]

# %%
"Taj Mahal is a beautiful monument".split()
# Out:
# ['Taj', 'Mahal', 'is', 'a', 'beautiful', 'monument']

# %%
print(nltk.pos_tag("Taj Mahal is a beautiful monument".split()))
# Out:
# [('Taj', 'NNP'), ('Mahal', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('monument', 'NN')]
