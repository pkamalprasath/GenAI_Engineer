# %%
# !pip install huggingface_hub
# !pip install langchain_huggingface
# Out:
# Requirement already satisfied: huggingface_hub in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (0.36.0)
# Requirement already satisfied: filelock in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface_hub) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface_hub) (2025.12.0)
# Requirement already satisfied: packaging>=20.9 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface_hub) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: colorama in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from requests->huggingface_hub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from requests->huggingface_hub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from requests->huggingface_hub) (2025.11.12)
# Requirement already satisfied: langchain_huggingface in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (1.2.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langchain_huggingface) (0.36.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langchain_huggingface) (1.2.5)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langchain_huggingface) (0.22.1)
# Requirement already satisfied: filelock in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2025.12.0)
# Requirement already satisfied: packaging>=20.9 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: requests in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.5.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.25.0)
# Requirement already satisfied: anyio in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (4.12.0)
# Requirement already satisfied: certifi in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2.3.0)
# Requirement already satisfied: colorama in d:\ai\krishnaik_academy\coding\langchain\venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (0.4.6)

# %%
from langchain_huggingface import HuggingFaceEndpoint
from dotenv import load_dotenv
import os

load_dotenv()

llm = HuggingFaceEndpoint(
    repo_id="google/gemma-2-9b",
    huggingfacehub_api_token=os.getenv("HF_TOKEN"),
    max_new_tokens=256,
    temperature=0.7,
)


print(llm.invoke("Explain relativity in simple terms."))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\huggingface_hub\utils\_http.py:402, in hf_raise_for_status(response, endpoint_name)
#     401 try:
# --> 402     response.raise_for_status()
#     403 except HTTPError as e:
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://router.huggingface.co/featherless-ai/v1/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[16], line 15
#       5 load_dotenv()
#       7 llm = HuggingFaceEndpoint(
#       8     repo_id="google/gemma-2-9b",
#       9     huggingfacehub_api_token=os.getenv("HF_TOKEN"),
#      10     max_new_tokens=256,
#      11     temperature=0.7,
#      12 )
# ---> 15 print(llm.invoke("Explain relativity in simple terms."))
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\langchain_core\language_models\llms.py:375, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     364 @override
#     365 def invoke(
#     366     self,
#    (...)    371     **kwargs: Any,
#     372 ) -> str:
#     373     config = ensure_config(config)
#     374     return (
# --> 375         self.generate_prompt(
#     376             [self._convert_input(input)],
#     377             stop=stop,
#     378             callbacks=config.get("callbacks"),
#     379             tags=config.get("tags"),
#     380             metadata=config.get("metadata"),
#     381             run_name=config.get("run_name"),
#     382             run_id=config.pop("run_id", None),
#     383             **kwargs,
#     384         )
#     385         .generations[0][0]
#     386         .text
#     387     )
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\langchain_core\language_models\llms.py:786, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     777 @override
#     778 def generate_prompt(
#     779     self,
#    (...)    783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_strings = [p.to_string() for p in prompts]
# --> 786     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\langchain_core\language_models\llms.py:1008, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     989 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     990     run_managers = [
#     991         callback_manager.on_llm_start(
#     992             self._serialized,
#    (...)   1006         )
#    1007     ]
# -> 1008     return self._generate_helper(
#    1009         prompts,
#    1010         stop,
#    1011         run_managers,
#    1012         new_arg_supported=bool(new_arg_supported),
#    1013         **kwargs,
#    1014     )
#    1015 if len(missing_prompts) > 0:
#    1016     run_managers = [
#    1017         callback_managers[idx].on_llm_start(
#    1018             self._serialized,
#    (...)   1025         for idx in missing_prompt_idxs
#    1026     ]
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\langchain_core\language_models\llms.py:812, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     801 def _generate_helper(
#     802     self,
#     803     prompts: list[str],
#    (...)    808     **kwargs: Any,
#     809 ) -> LLMResult:
#     810     try:
#     811         output = (
# --> 812             self._generate(
#     813                 prompts,
#     814                 stop=stop,
#     815                 # TODO: support multiple run managers
#     816                 run_manager=run_managers[0] if run_managers else None,
#     817                 **kwargs,
#     818             )
#     819             if new_arg_supported
#     820             else self._generate(prompts, stop=stop)
#     821         )
#     822     except BaseException as e:
#     823         for run_manager in run_managers:
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\langchain_core\language_models\llms.py:1502, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#    1499 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#    1500 for prompt in prompts:
#    1501     text = (
# -> 1502         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1503         if new_arg_supported
#    1504         else self._call(prompt, stop=stop, **kwargs)
#    1505     )
#    1506     generations.append([Generation(text=text)])
#    1507 return LLMResult(generations=generations)
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\langchain_huggingface\llms\huggingface_endpoint.py:341, in HuggingFaceEndpoint._call(self, prompt, stop, run_manager, **kwargs)
#     338         completion += chunk.text
#     339     return completion
# --> 341 response_text = self.client.text_generation(
#     342     prompt=prompt,
#     343     model=self.model,
#     344     **invocation_params,
#     345 )
#     347 # Maybe the generation has stopped at one of the stop sequences:
#     348 # then we remove this stop sequence from the end of the generated text
#     349 for stop_seq in invocation_params["stop"]:
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\huggingface_hub\inference\_client.py:2398, in InferenceClient.text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2373         _set_unsupported_text_generation_kwargs(model, unused_params)
#    2374         return self.text_generation(  # type: ignore
#    2375             prompt=prompt,
#    2376             details=details,
#    (...)   2396             watermark=watermark,
#    2397         )
# -> 2398     raise_text_generation_error(e)
#    2400 # Parse output
#    2401 if stream:
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\huggingface_hub\inference\_common.py:447, in raise_text_generation_error(http_error)
#     444     raise exception from http_error
#     446 # Otherwise, fallback to default error
# --> 447 raise http_error
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\huggingface_hub\inference\_client.py:2368, in InferenceClient.text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2366 # Handle errors separately for more precise error messages
#    2367 try:
# -> 2368     bytes_output = self._inner_post(request_parameters, stream=stream or False)
#    2369 except HTTPError as e:
#    2370     match = MODEL_KWARGS_NOT_USED_REGEX.search(str(e))
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\huggingface_hub\inference\_client.py:275, in InferenceClient._inner_post(self, request_parameters, stream)
#     272     raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     274 try:
# --> 275     hf_raise_for_status(response)
#     276     return response.iter_lines() if stream else response.content
#     277 except HTTPError as error:
#
# File d:\AI\KrishNaik_Academy\Coding\LANGCHAIN\venv\Lib\site-packages\huggingface_hub\utils\_http.py:466, in hf_raise_for_status(response, endpoint_name)
#     460 elif response.status_code == 403:
#     461     message = (
#     462         f"\n\n{response.status_code} Forbidden: {error_message}."
#     463         + f"\nCannot access content at: {response.url}."
#     464         + "\nMake sure your token has the correct permissions."
#     465     )
# --> 466     raise _format(HfHubHTTPError, message, response) from e
#     468 elif response.status_code == 416:
#     469     range_header = response.request.headers.get("Range")
#
# HfHubHTTPError: (Request ID: Root=1-695b0c8b-7f629ac950f6b8381f6db457;76a4afa4-a883-4268-8a81-5a68a59f9b95)
#
# 403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Kamalprasath.
# Cannot access content at: https://router.huggingface.co/featherless-ai/v1/completions.
# Make sure your token has the correct permissions.

# %%
from pydantic import BaseModel
book = Book(title="Dune", author="Frank Herbert", pages="412")
fields = {
    "title": "The Hobbit",
    "author": "J.R.R. Tolkien",
    "pages": 310
}

book = Book(**fields)
print(book)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 from pydantic import BaseModel
# ----> 2 book = Book(title="Dune", author="Frank Herbert", pages="412")
#       3 fields = {
#       4     "title": "The Hobbit",
#       5     "author": "J.R.R. Tolkien",
#       6     "pages": 310
#       7 }
#       9 book = Book(**fields)
#
# TypeError: Book.__init__() got an unexpected keyword argument 'pages'
