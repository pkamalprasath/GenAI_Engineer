# %% [markdown]
# """
# This script demonstrates how to use Haystack's FaithfulnessEvaluator
# to check whether an LLM-generated answer is faithful to the provided context.
#
# Faithfulness means:
# - The answer should be supported by the given context
# - The answer should not hallucinate or introduce unsupported facts
#
# This is commonly used in RAG (Retrieval-Augmented Generation) pipelines
# to evaluate answer quality and trustworthiness.
# """

# %%
# !pip install haystack-ai
# Out:
# Collecting haystack-ai
#   Using cached haystack_ai-2.22.0-py3-none-any.whl.metadata (15 kB)
# Collecting docstring-parser (from haystack-ai)
#   Using cached docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting filetype (from haystack-ai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting haystack-experimental (from haystack-ai)
#   Using cached haystack_experimental-0.17.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jinja2 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-ai) (3.1.6)
# Requirement already satisfied: jsonschema in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-ai) (4.25.1)
# Collecting lazy-imports (from haystack-ai)
#   Downloading lazy_imports-1.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting more-itertools (from haystack-ai)
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: networkx in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-ai) (3.6.1)
# Requirement already satisfied: numpy in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-ai) (2.3.5)
# Collecting openai>=1.99.2 (from haystack-ai)
#   Using cached openai-2.15.0-py3-none-any.whl.metadata (29 kB)
# Collecting posthog!=3.12.0 (from haystack-ai)
#   Downloading posthog-7.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting pydantic (from haystack-ai)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: python-dateutil in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-ai) (2.9.0.post0)
# Collecting pyyaml (from haystack-ai)
#   Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: requests in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-ai) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-ai) (9.1.2)
# Requirement already satisfied: tqdm in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-ai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.7 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-ai) (4.15.0)
# Collecting anyio<5,>=3.5.0 (from openai>=1.99.2->haystack-ai)
#   Using cached anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.99.2->haystack-ai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.99.2->haystack-ai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.10.0 (from openai>=1.99.2->haystack-ai)
#   Using cached jiter-0.12.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting sniffio (from openai>=1.99.2->haystack-ai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: idna>=2.8 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.99.2->haystack-ai) (3.11)
# Requirement already satisfied: certifi in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.99.2->haystack-ai) (2025.11.12)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.99.2->haystack-ai)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.99.2->haystack-ai)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->haystack-ai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic->haystack-ai)
#   Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic->haystack-ai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from posthog!=3.12.0->haystack-ai) (1.17.0)
# Collecting backoff>=1.10.0 (from posthog!=3.12.0->haystack-ai)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from requests->haystack-ai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from requests->haystack-ai) (2.6.2)
# Requirement already satisfied: colorama in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from tqdm->haystack-ai) (0.4.6)
# Requirement already satisfied: rich in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from haystack-experimental->haystack-ai) (14.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from jinja2->haystack-ai) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from jsonschema->haystack-ai) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from jsonschema->haystack-ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from jsonschema->haystack-ai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from jsonschema->haystack-ai) (0.30.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from rich->haystack-experimental->haystack-ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from rich->haystack-experimental->haystack-ai) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->haystack-experimental->haystack-ai) (0.1.2)
# Using cached haystack_ai-2.22.0-py3-none-any.whl (643 kB)
# Using cached openai-2.15.0-py3-none-any.whl (1.1 MB)
# Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached jiter-0.12.0-cp311-cp311-win_amd64.whl (204 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading posthog-7.6.0-py3-none-any.whl (168 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached haystack_experimental-0.17.0-py3-none-any.whl (73 kB)
# Downloading lazy_imports-1.2.0-py3-none-any.whl (18 kB)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: filetype, typing-inspection, sniffio, pyyaml, pydantic-core, more-itertools, lazy-imports, jiter, h11, docstring-parser, distro, backoff, anyio, annotated-types, pydantic, posthog, httpcore, httpx, openai, haystack-experimental, haystack-ai
#
#    --- ------------------------------------  2/21 [sniffio]
#    ----- ----------------------------------  3/21 [pyyaml]
#    --------- ------------------------------  5/21 [more-itertools]
#    ----------- ----------------------------  6/21 [lazy-imports]
#    ----------------- ----------------------  9/21 [docstring-parser]
#    ----------------- ----------------------  9/21 [docstring-parser]
#    -------------------- ------------------- 11/21 [backoff]
#    ---------------------- ----------------- 12/21 [anyio]
#    ---------------------- ----------------- 12/21 [anyio]
#    ---------------------- ----------------- 12/21 [anyio]
#    ------------------------ --------------- 13/21 [annotated-types]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    -------------------------- ------------- 14/21 [pydantic]
#    ---------------------------- ----------- 15/21 [posthog]
#    ---------------------------- ----------- 15/21 [posthog]
#    ---------------------------- ----------- 15/21 [posthog]
#    ---------------------------- ----------- 15/21 [posthog]
#    ------------------------------ --------- 16/21 [httpcore]
#    ------------------------------ --------- 16/21 [httpcore]
#    -------------------------------- ------- 17/21 [httpx]
#    -------------------------------- ------- 17/21 [httpx]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ---------------------------------- ----- 18/21 [openai]
#    ------------------------------------ --- 19/21 [haystack-experimental]
#    ------------------------------------ --- 19/21 [haystack-experimental]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    -------------------------------------- - 20/21 [haystack-ai]
#    ---------------------------------------- 21/21 [haystack-ai]
#
# Successfully installed annotated-types-0.7.0 anyio-4.12.1 backoff-2.2.1 distro-1.9.0 docstring-parser-0.17.0 filetype-1.2.0 h11-0.16.0 haystack-ai-2.22.0 haystack-experimental-0.17.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.12.0 lazy-imports-1.2.0 more-itertools-10.8.0 openai-2.15.0 posthog-7.6.0 pydantic-2.12.5 pydantic-core-2.41.5 pyyaml-6.0.3 sniffio-1.3.1 typing-inspection-0.4.2

# %%
# !pip install dotenv langchain_openai
# Out:
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting langchain_openai
#   Using cached langchain_openai-1.1.7-py3-none-any.whl.metadata (2.6 kB)
# Collecting python-dotenv (from dotenv)
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting langchain-core<2.0.0,>=1.2.6 (from langchain_openai)
#   Using cached langchain_core-1.2.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from langchain_openai) (2.15.0)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain_openai)
#   Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.6->langchain_openai)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.6->langchain_openai)
#   Using cached langsmith-0.6.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.6->langchain_openai)
#   Using cached uuid_utils-0.14.0-cp39-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.6->langchain_openai)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai)
#   Using cached orjson-3.11.5-cp311-cp311-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai)
#   Using cached zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (4.12.1)
# Requirement already satisfied: certifi in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.12.0)
# Requirement already satisfied: sniffio in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.6.2)
# Requirement already satisfied: colorama in d:\ai\krishnaik_academy\coding\venv\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain_openai) (0.4.6)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Using cached langchain_openai-1.1.7-py3-none-any.whl (84 kB)
# Using cached langchain_core-1.2.7-py3-none-any.whl (490 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langsmith-0.6.4-py3-none-any.whl (283 kB)
# Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
# Using cached uuid_utils-0.14.0-cp39-abi3-win_amd64.whl (182 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached orjson-3.11.5-cp311-cp311-win_amd64.whl (133 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: zstandard, uuid-utils, python-dotenv, orjson, jsonpointer, tiktoken, requests-toolbelt, jsonpatch, dotenv, langsmith, langchain-core, langchain_openai
#
#    ------ ---------------------------------  2/12 [python-dotenv]
#    ---------------- -----------------------  5/12 [tiktoken]
#    -------------------- -------------------  6/12 [requests-toolbelt]
#    ------------------------------ ---------  9/12 [langsmith]
#    ------------------------------ ---------  9/12 [langsmith]
#    ------------------------------ ---------  9/12 [langsmith]
#    ------------------------------ ---------  9/12 [langsmith]
#    ------------------------------ ---------  9/12 [langsmith]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    ------------------------------------ --- 11/12 [langchain_openai]
#    ------------------------------------ --- 11/12 [langchain_openai]
#    ---------------------------------------- 12/12 [langchain_openai]
#
# Successfully installed dotenv-0.9.9 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-1.2.7 langchain_openai-1.1.7 langsmith-0.6.4 orjson-3.11.5 python-dotenv-1.2.1 requests-toolbelt-1.0.0 tiktoken-0.12.0 uuid-utils-0.14.0 zstandard-0.25.0

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()  # loads .env into environment variables

os.environ["OPENAI_API_KEY"]= os.getenv('OPENAI_API_KEY')

llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0.2
)

# %%
from haystack.components.evaluators import FaithfulnessEvaluator

questions = ["Who created Python Programming Language?"]
contexts = [
    [
        "Python, created by Guido van Rossum in the late 1980s, is a high-level general-purpose programming language. "
        "Its design philosophy emphasizes code readability, and its language constructs aim to help programmers write clear, logical code for both small and large-scale software projects."
    ],
]

predicted_answers = ["Python is a high-level general-purpose programming language that was created by Guido van Rossum"]
evaluator = FaithfulnessEvaluator()
result = evaluator.run(questions=questions, contexts=contexts, predicted_answers=predicted_answers)

print(result["individual_scores"])
# Out:
# PromptBuilder has 3 prompt variables, but `required_variables` is not set. By default, all prompt variables are treated as optional, which may lead to unintended behavior in multi-branch pipelines. To avoid unexpected execution, ensure that variables intended to be required are explicitly set in `required_variables`.
# 100%|██████████| 1/1 [00:05<00:00,  5.23s/it]
# [np.float64(1.0)]
